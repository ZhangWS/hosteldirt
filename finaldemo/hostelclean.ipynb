# %%
#this will clean all of the lovely data and merge it into a coherent pandas dataframe before I output it all to SQL

import csv
import pandas as pd
import re
import datetime
import ftfy
import pprint

from sqlalchemy import *
from sqlalchemy_utils import *
import psycopg2

# %%
###RUN THIS FIRST: postgres -D "C:\Users\Natalia\Desktop\Insight Data Science\postgres_data"

db = 'hostel'
username = 'Natalia'
engine = create_engine('postgres://%s@localhost/%s'%(username,db))
print(engine.url)
# Out:
# postgres://Natalia@localhost/hostel

# %%
hosteladdress1 = pd.read_csv('hosteladdress20180924-221852.csv')
hosteladdress2 = pd.read_csv('hosteladdress20180924-224509.csv')

# %%
addressname = 'hosteladdress.csv'

# %%
with open(addressname, 'w', newline='', encoding="UTF-8") as f:
    writer = csv.writer(f)
    writer.writerow(['hostelid','address'])
    for hostel in hosteladdress1.itertuples():
        temp = hostel.address.split("&quot;")
        if len(temp) > 1:
            temp = temp[1]
        else:
            temp = temp[0]
        print(temp)
        writer.writerow([hostel.hostelid, temp])
    
    for hostel in hosteladdress2.itertuples():
        temp = hostel.address.split("&quot;")
        if len(temp) > 1:
            temp = temp[1]
        else:
            temp = temp[0]
        print(temp)
        writer.writerow([hostel.hostelid, temp])

del writer

# %%
hostellinks1 = pd.read_csv('hostelinks20180924-211004.csv')
hostellinks2 = pd.read_csv('hostelinks20180924-211021.csv')

# %%
hostellinks = hostellinks1.append(hostellinks2, ignore_index=True)
hostellinks.to_csv("hostellinks.csv")
hostelreviews = pd.read_csv('hostelreviews.csv')
hosteladdress = pd.read_csv('hosteladdress.csv')

# %%
hostelreviews.to_sql('hostelreviews', engine, if_exists='replace')
hostellinks.to_sql('hostellinks', engine, if_exists='replace')
hosteladdress.to_sql('hosteladdress', engine, if_exists='replace')

# %%
q = text("SELECT * from hosteladdress r JOIN hostellinks l on r.hostelid = l.hostelid")
hostelset =  pd.DataFrame(engine.execute(q).fetchall())

# %%
chostelset.head()
# Out:
#      0      1                                     2  3  \
# 0  554  48151  357 College Street, Toronto, Ontario  0
# 1  555   3856                76 Church St., Toronto  1
# 2  556  42418                            5 Selby St  2
# 3  557  92762                    280 Augusta Avenue  3
# 4  558  71032                     7 Clarence Square  4
#
#                         4      5        6  \
# 0  Planet Traveler Hostel  48151  Toronto
# 1              HI Toronto   3856  Toronto
# 2         All Days Hostel  42418  Toronto
# 3     College Backpackers  92762  Toronto
# 4       The Clarence Park  71032  Toronto
#
#                                                    7     8
# 0  https://www.hostelworld.com/hosteldetails.php/...  None
# 1  https://www.hostelworld.com/hosteldetails.php/...  None
# 2  https://www.hostelworld.com/hosteldetails.php/...  None
# 3  https://www.hostelworld.com/hosteldetails.php/...  None
# 4  https://www.hostelworld.com/hosteldetails.php/...  None

# %%
col=[0,3,5,8]
hostelset.drop(hostelset.columns[col], axis=1, inplace=True)

# %%
hostelset.columns = ["hostelid", "address", "name", "city", "url"]
hostelset.head()
# Out:
#    hostelid                               address                    name  \
# 0     48151  357 College Street, Toronto, Ontario  Planet Traveler Hostel
# 1      3856                76 Church St., Toronto              HI Toronto
# 2     42418                            5 Selby St         All Days Hostel
# 3     92762                    280 Augusta Avenue     College Backpackers
# 4     71032                     7 Clarence Square       The Clarence Park
#
#       city                                                url
# 0  Toronto  https://www.hostelworld.com/hosteldetails.php/...
# 1  Toronto  https://www.hostelworld.com/hosteldetails.php/...
# 2  Toronto  https://www.hostelworld.com/hosteldetails.php/...
# 3  Toronto  https://www.hostelworld.com/hosteldetails.php/...
# 4  Toronto  https://www.hostelworld.com/hosteldetails.php/...

# %%
hostelset.to_sql('hostellinks', engine, if_exists='replace')

# %%
hostelset.to_csv('hostellinks-all.csv')

# %%
hostelset.shape
# Out:
# (892, 5)

# %%
q = text("SELECT * from hostelreviews r JOIN hostellinks l on r.hostelid = l.hostelid")
reviewset =  pd.DataFrame(engine.execute(q).fetchall())

# %%
reviewset.head()
# Out:
#    0   1                       2      3        4                    5   \
# 0   0   0  Planet Traveler Hostel  48151  Toronto  2018-09-13 00:00:00
# 1   1   1  Planet Traveler Hostel  48151  Toronto  2018-09-12 00:00:00
# 2   2   2  Planet Traveler Hostel  48151  Toronto  2018-09-12 00:00:00
# 3   3   3  Planet Traveler Hostel  48151  Toronto  2018-09-09 00:00:00
# 4   4   4  Planet Traveler Hostel  48151  Toronto  2018-09-04 00:00:00
#
#                6                                                  7   8   9   \
# 0  review11816582  Good location in the middle of the city. Catch...  10  10
# 1  review11811012  Secure, good staff, good atmosphere, lovely vi...   6   8
# 2  review11809075  Clean, very friendly staff and free activities...   8   8
# 3  review11801051  This is the first and only time I stay at a ho...   6  10
# 4  review11800849  Planet Traveller provided everything a tourist...   8  10
#
#                          ...                          11  12  13  14  15  \
# 0                        ...                          10  10  10  10   0
# 1                        ...                           8   8  10  10   0
# 2                        ...                           6  10  10  10   0
# 3                        ...                           6   6   8  10   0
# 4                        ...                           8  10  10   8   0
#
#       16                                    17                      18  \
# 0  48151  357 College Street, Toronto, Ontario  Planet Traveler Hostel
# 1  48151  357 College Street, Toronto, Ontario  Planet Traveler Hostel
# 2  48151  357 College Street, Toronto, Ontario  Planet Traveler Hostel
# 3  48151  357 College Street, Toronto, Ontario  Planet Traveler Hostel
# 4  48151  357 College Street, Toronto, Ontario  Planet Traveler Hostel
#
#         19                                                 20
# 0  Toronto  https://www.hostelworld.com/hosteldetails.php/...
# 1  Toronto  https://www.hostelworld.com/hosteldetails.php/...
# 2  Toronto  https://www.hostelworld.com/hosteldetails.php/...
# 3  Toronto  https://www.hostelworld.com/hosteldetails.php/...
# 4  Toronto  https://www.hostelworld.com/hosteldetails.php/...
#
# [5 rows x 21 columns]

# %%
col=[0,1,3,15, 16,18, 19]
reviewset.drop(reviewset.columns[col], axis=1, inplace=True)

# %%
reviewset.columns = ["name", "city", "date", "reviewid", "reviewtext",'value', 'security', 'location', 'facilities', 'staff',
       'atmosphere', 'cleanliness',"address","url"]

# %%
reviewset.head()
# Out:
#                      name     city                 date        reviewid  \
# 0  Planet Traveler Hostel  Toronto  2018-09-13 00:00:00  review11816582
# 1  Planet Traveler Hostel  Toronto  2018-09-12 00:00:00  review11811012
# 2  Planet Traveler Hostel  Toronto  2018-09-12 00:00:00  review11809075
# 3  Planet Traveler Hostel  Toronto  2018-09-09 00:00:00  review11801051
# 4  Planet Traveler Hostel  Toronto  2018-09-04 00:00:00  review11800849
#
#                                           reviewtext  value  security  \
# 0  Good location in the middle of the city. Catch...     10        10
# 1  Secure, good staff, good atmosphere, lovely vi...      6         8
# 2  Clean, very friendly staff and free activities...      8         8
# 3  This is the first and only time I stay at a ho...      6        10
# 4  Planet Traveller provided everything a tourist...      8        10
#
#    location  facilities  staff  atmosphere  cleanliness  \
# 0        10          10     10          10           10
# 1         6           8      8          10           10
# 2         8           6     10          10           10
# 3         8           6      6           8           10
# 4        10           8     10          10            8
#
#                                 address  \
# 0  357 College Street, Toronto, Ontario
# 1  357 College Street, Toronto, Ontario
# 2  357 College Street, Toronto, Ontario
# 3  357 College Street, Toronto, Ontario
# 4  357 College Street, Toronto, Ontario
#
#                                                  url
# 0  https://www.hostelworld.com/hosteldetails.php/...
# 1  https://www.hostelworld.com/hosteldetails.php/...
# 2  https://www.hostelworld.com/hosteldetails.php/...
# 3  https://www.hostelworld.com/hosteldetails.php/...
# 4  https://www.hostelworld.com/hosteldetails.php/...

# %%
reviewset.to_csv('hostelreviews-all.csv')

# %%
reviewset.to_sql('hostelreviews', engine, if_exists='replace')
